# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

from pandas.plotting import table

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
oecddata = pd.read_csv("OECD STAT CSV.csv")
oecddata.head()
# Out:
#   LOCATION         Country INDICATOR                 Indicator MEASURE  \
# 0      AUS       Australia   JE_LMIS  Labour market insecurity       L
# 1      AUT         Austria   JE_LMIS  Labour market insecurity       L
# 2      BEL         Belgium   JE_LMIS  Labour market insecurity       L
# 3      CAN          Canada   JE_LMIS  Labour market insecurity       L
# 4      CZE  Czech Republic   JE_LMIS  Labour market insecurity       L
#
#   Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0   Value        TOT      Total        PC  Percentage               0
# 1   Value        TOT      Total        PC  Percentage               0
# 2   Value        TOT      Total        PC  Percentage               0
# 3   Value        TOT      Total        PC  Percentage               0
# 4   Value        TOT      Total        PC  Percentage               0
#
#   PowerCode  Reference Period Code  Reference Period  Value  Flag Codes  Flags
# 0     Units                    NaN               NaN    5.4         NaN    NaN
# 1     Units                    NaN               NaN    3.5         NaN    NaN
# 2     Units                    NaN               NaN    3.7         NaN    NaN
# 3     Units                    NaN               NaN    6.0         NaN    NaN
# 4     Units                    NaN               NaN    3.1         NaN    NaN

# %%
oecddata.columns
# Out:
# Index(['LOCATION', 'Country', 'INDICATOR', 'Indicator', 'MEASURE', 'Measure',
#        'INEQUALITY', 'Inequality', 'Unit Code', 'Unit', 'PowerCode Code',
#        'PowerCode', 'Reference Period Code', 'Reference Period', 'Value',
#        'Flag Codes', 'Flags'],
#       dtype='object')

# %%
oecddata1 = oecddata[["Country", "Indicator", "Inequality", "Value"]]
len(oecddata1)
# Out:
# 2368

# %%
oecddata2 = oecddata1.loc[oecddata["Inequality"] == "Total"]
len(oecddata2)
# Out:
# 910

# %%
del oecddata2["Inequality"]
oecddata2.head()
# Out:
#           Country                 Indicator  Value
# 0       Australia  Labour market insecurity    5.4
# 1         Austria  Labour market insecurity    3.5
# 2         Belgium  Labour market insecurity    3.7
# 3          Canada  Labour market insecurity    6.0
# 4  Czech Republic  Labour market insecurity    3.1

# %%
outputfile = oecddata2.to_csv("oecddatareduced0712.csv", encoding="utf-8", index=False)

# %%
shjoecddata = pd.read_csv("shjoecddata0712.csv")
happiness = pd.read_csv("happiness2018score.csv")

# %%
happiness
# Out:
#                       Country Indicator  Value
# 0                     Finland     Score  7.632
# 1                      Norway     Score  7.594
# 2                     Denmark     Score  7.555
# 3                     Iceland     Score  7.495
# 4                 Switzerland     Score  7.487
# 5                 Netherlands     Score  7.441
# 6                      Canada     Score  7.328
# 7                 New Zealand     Score  7.324
# 8                      Sweden     Score  7.314
# 9                   Australia     Score  7.272
# 10                     Israel     Score  7.190
# 11                    Austria     Score  7.139
# 12                 Costa Rica     Score  7.072
# 13                    Ireland     Score  6.977
# 14                    Germany     Score  6.965
# 15                    Belgium     Score  6.927
# 16                 Luxembourg     Score  6.910
# 17              United States     Score  6.886
# 18             United Kingdom     Score  6.814
# 19       United Arab Emirates     Score  6.774
# 20             Czech Republic     Score  6.711
# 21                      Malta     Score  6.627
# 22                     France     Score  6.489
# 23                     Mexico     Score  6.488
# 24                      Chile     Score  6.476
# 25                     Taiwan     Score  6.441
# 26                     Panama     Score  6.430
# 27                     Brazil     Score  6.419
# 28                  Argentina     Score  6.388
# 29                  Guatemala     Score  6.382
# ..                        ...       ...    ...
# 126                  Ethiopia     Score  4.350
# 127                   Georgia     Score  4.340
# 128                   Armenia     Score  4.321
# 129                   Myanmar     Score  4.308
# 130                      Chad     Score  4.301
# 131          Congo (Kinshasa)     Score  4.245
# 132                     India     Score  4.190
# 133                     Niger     Score  4.166
# 134                    Uganda     Score  4.161
# 135                     Benin     Score  4.141
# 136                     Sudan     Score  4.139
# 137                   Ukraine     Score  4.103
# 138                      Togo     Score  3.999
# 139                    Guinea     Score  3.964
# 140                   Lesotho     Score  3.808
# 141                    Angola     Score  3.795
# 142                Madagascar     Score  3.774
# 143                  Zimbabwe     Score  3.692
# 144               Afghanistan     Score  3.632
# 145                  Botswana     Score  3.590
# 146                    Malawi     Score  3.587
# 147                     Haiti     Score  3.582
# 148                   Liberia     Score  3.495
# 149                     Syria     Score  3.462
# 150                    Rwanda     Score  3.408
# 151                     Yemen     Score  3.355
# 152                  Tanzania     Score  3.303
# 153               South Sudan     Score  3.254
# 154  Central African Republic     Score  3.083
# 155                   Burundi     Score  2.905
#
# [156 rows x 3 columns]

# %%
shjmergedoecd = oecddata2.append(happiness)
shjmergedoecd
# Out:
#                       Country                 Indicator   Value
# 0                   Australia  Labour market insecurity   5.400
# 1                     Austria  Labour market insecurity   3.500
# 2                     Belgium  Labour market insecurity   3.700
# 3                      Canada  Labour market insecurity   6.000
# 4              Czech Republic  Labour market insecurity   3.100
# 5                     Denmark  Labour market insecurity   4.200
# 6                     Finland  Labour market insecurity   3.900
# 7                      France  Labour market insecurity   7.600
# 8                     Germany  Labour market insecurity   2.700
# 9                      Greece  Labour market insecurity  29.800
# 10                    Hungary  Labour market insecurity   4.700
# 11                    Iceland  Labour market insecurity   0.700
# 12                    Ireland  Labour market insecurity   7.800
# 13                      Italy  Labour market insecurity  12.300
# 14                      Japan  Labour market insecurity   1.400
# 15                      Korea  Labour market insecurity   2.600
# 16                 Luxembourg  Labour market insecurity   1.700
# 17                     Mexico  Labour market insecurity   5.500
# 18                Netherlands  Labour market insecurity   4.800
# 19                New Zealand  Labour market insecurity   4.700
# 20                     Poland  Labour market insecurity   5.700
# 21                   Portugal  Labour market insecurity  10.000
# 22            Slovak Republic  Labour market insecurity   9.900
# 23                      Spain  Labour market insecurity  23.100
# 24                     Sweden  Labour market insecurity   3.200
# 25                     Turkey  Labour market insecurity  12.500
# 26             United Kingdom  Labour market insecurity   4.500
# 27              United States  Labour market insecurity   7.700
# 28                      Chile  Labour market insecurity   8.700
# 29                    Estonia  Labour market insecurity   3.800
# ..                        ...                       ...     ...
# 126                  Ethiopia                     Score   4.350
# 127                   Georgia                     Score   4.340
# 128                   Armenia                     Score   4.321
# 129                   Myanmar                     Score   4.308
# 130                      Chad                     Score   4.301
# 131          Congo (Kinshasa)                     Score   4.245
# 132                     India                     Score   4.190
# 133                     Niger                     Score   4.166
# 134                    Uganda                     Score   4.161
# 135                     Benin                     Score   4.141
# 136                     Sudan                     Score   4.139
# 137                   Ukraine                     Score   4.103
# 138                      Togo                     Score   3.999
# 139                    Guinea                     Score   3.964
# 140                   Lesotho                     Score   3.808
# 141                    Angola                     Score   3.795
# 142                Madagascar                     Score   3.774
# 143                  Zimbabwe                     Score   3.692
# 144               Afghanistan                     Score   3.632
# 145                  Botswana                     Score   3.590
# 146                    Malawi                     Score   3.587
# 147                     Haiti                     Score   3.582
# 148                   Liberia                     Score   3.495
# 149                     Syria                     Score   3.462
# 150                    Rwanda                     Score   3.408
# 151                     Yemen                     Score   3.355
# 152                  Tanzania                     Score   3.303
# 153               South Sudan                     Score   3.254
# 154  Central African Republic                     Score   3.083
# 155                   Burundi                     Score   2.905
#
# [1066 rows x 3 columns]

# %%
shjoecddata0713 = shjmergedoecd.pivot(index="Country", columns="Indicator", values="Value")
shjoecddata0713
# Out:
# Indicator                 Air pollution  Dwellings without basic facilities  \
# Country
# Afghanistan                         NaN                                 NaN
# Albania                             NaN                                 NaN
# Algeria                             NaN                                 NaN
# Angola                              NaN                                 NaN
# Argentina                           NaN                                 NaN
# Armenia                             NaN                                 NaN
# Australia                           5.0                                 NaN
# Austria                            16.0                                 0.9
# Azerbaijan                          NaN                                 NaN
# Bahrain                             NaN                                 NaN
# Bangladesh                          NaN                                 NaN
# Belarus                             NaN                                 NaN
# Belgium                            15.0                                 1.9
# Belize                              NaN                                 NaN
# Benin                               NaN                                 NaN
# Bhutan                              NaN                                 NaN
# Bolivia                             NaN                                 NaN
# Bosnia and Herzegovina              NaN                                 NaN
# Botswana                            NaN                                 NaN
# Brazil                             10.0                                 6.7
# Bulgaria                            NaN                                 NaN
# Burkina Faso                        NaN                                 NaN
# Burundi                             NaN                                 NaN
# Cambodia                            NaN                                 NaN
# Cameroon                            NaN                                 NaN
# Canada                              7.0                                 0.2
# Central African Republic            NaN                                 NaN
# Chad                                NaN                                 NaN
# Chile                              16.0                                 9.4
# China                               NaN                                 NaN
# ...                                 ...                                 ...
# South Africa                       22.0                                37.0
# South Korea                         NaN                                 NaN
# South Sudan                         NaN                                 NaN
# Spain                              11.0                                 0.1
# Sri Lanka                           NaN                                 NaN
# Sudan                               NaN                                 NaN
# Sweden                              6.0                                 0.0
# Switzerland                        15.0                                 0.1
# Syria                               NaN                                 NaN
# Taiwan                              NaN                                 NaN
# Tajikistan                          NaN                                 NaN
# Tanzania                            NaN                                 NaN
# Thailand                            NaN                                 NaN
# Togo                                NaN                                 NaN
# Trinidad and Tobago                 NaN                                 NaN
# Tunisia                             NaN                                 NaN
# Turkey                             20.0                                 8.0
# Turkmenistan                        NaN                                 NaN
# Uganda                              NaN                                 NaN
# Ukraine                             NaN                                 NaN
# United Arab Emirates                NaN                                 NaN
# United Kingdom                     11.0                                 0.3
# United States                      10.0                                 0.1
# Uruguay                             NaN                                 NaN
# Uzbekistan                          NaN                                 NaN
# Venezuela                           NaN                                 NaN
# Vietnam                             NaN                                 NaN
# Yemen                               NaN                                 NaN
# Zambia                              NaN                                 NaN
# Zimbabwe                            NaN                                 NaN
#
# Indicator                 Educational attainment  \
# Country
# Afghanistan                                  NaN
# Albania                                      NaN
# Algeria                                      NaN
# Angola                                       NaN
# Argentina                                    NaN
# Armenia                                      NaN
# Australia                                   81.0
# Austria                                     85.0
# Azerbaijan                                   NaN
# Bahrain                                      NaN
# Bangladesh                                   NaN
# Belarus                                      NaN
# Belgium                                     77.0
# Belize                                       NaN
# Benin                                        NaN
# Bhutan                                       NaN
# Bolivia                                      NaN
# Bosnia and Herzegovina                       NaN
# Botswana                                     NaN
# Brazil                                      49.0
# Bulgaria                                     NaN
# Burkina Faso                                 NaN
# Burundi                                      NaN
# Cambodia                                     NaN
# Cameroon                                     NaN
# Canada                                      91.0
# Central African Republic                     NaN
# Chad                                         NaN
# Chile                                       65.0
# China                                        NaN
# ...                                          ...
# South Africa                                73.0
# South Korea                                  NaN
# South Sudan                                  NaN
# Spain                                       59.0
# Sri Lanka                                    NaN
# Sudan                                        NaN
# Sweden                                      83.0
# Switzerland                                 88.0
# Syria                                        NaN
# Taiwan                                       NaN
# Tajikistan                                   NaN
# Tanzania                                     NaN
# Thailand                                     NaN
# Togo                                         NaN
# Trinidad and Tobago                          NaN
# Tunisia                                      NaN
# Turkey                                      39.0
# Turkmenistan                                 NaN
# Uganda                                       NaN
# Ukraine                                      NaN
# United Arab Emirates                         NaN
# United Kingdom                              81.0
# United States                               91.0
# Uruguay                                      NaN
# Uzbekistan                                   NaN
# Venezuela                                    NaN
# Vietnam                                      NaN
# Yemen                                        NaN
# Zambia                                       NaN
# Zimbabwe                                     NaN
#
# Indicator                 Employees working very long hours  Employment rate  \
# Country
# Afghanistan                                             NaN              NaN
# Albania                                                 NaN              NaN
# Algeria                                                 NaN              NaN
# Angola                                                  NaN              NaN
# Argentina                                               NaN              NaN
# Armenia                                                 NaN              NaN
# Australia                                             13.04             73.0
# Austria                                                6.66             72.0
# Azerbaijan                                              NaN              NaN
# Bahrain                                                 NaN              NaN
# Bangladesh                                              NaN              NaN
# Belarus                                                 NaN              NaN
# Belgium                                                4.75             63.0
# Belize                                                  NaN              NaN
# Benin                                                   NaN              NaN
# Bhutan                                                  NaN              NaN
# Bolivia                                                 NaN              NaN
# Bosnia and Herzegovina                                  NaN              NaN
# Botswana                                                NaN              NaN
# Brazil                                                 7.13             61.0
# Bulgaria                                                NaN              NaN
# Burkina Faso                                            NaN              NaN
# Burundi                                                 NaN              NaN
# Cambodia                                                NaN              NaN
# Cameroon                                                NaN              NaN
# Canada                                                 3.69             73.0
# Central African Republic                                NaN              NaN
# Chad                                                    NaN              NaN
# Chile                                                  9.72             63.0
# China                                                   NaN              NaN
# ...                                                     ...              ...
# South Africa                                          18.12             43.0
# South Korea                                             NaN              NaN
# South Sudan                                             NaN              NaN
# Spain                                                  4.01             62.0
# Sri Lanka                                               NaN              NaN
# Sudan                                                   NaN              NaN
# Sweden                                                 1.07             77.0
# Switzerland                                            0.37             80.0
# Syria                                                   NaN              NaN
# Taiwan                                                  NaN              NaN
# Tajikistan                                              NaN              NaN
# Tanzania                                                NaN              NaN
# Thailand                                                NaN              NaN
# Togo                                                    NaN              NaN
# Trinidad and Tobago                                     NaN              NaN
# Tunisia                                                 NaN              NaN
# Turkey                                                32.64             52.0
# Turkmenistan                                            NaN              NaN
# Uganda                                                  NaN              NaN
# Ukraine                                                 NaN              NaN
# United Arab Emirates                                    NaN              NaN
# United Kingdom                                        12.15             75.0
# United States                                         11.09             70.0
# Uruguay                                                 NaN              NaN
# Uzbekistan                                              NaN              NaN
# Venezuela                                               NaN              NaN
# Vietnam                                                 NaN              NaN
# Yemen                                                   NaN              NaN
# Zambia                                                  NaN              NaN
# Zimbabwe                                                NaN              NaN
#
# Indicator                 Feeling safe walking alone at night  Homicide rate  \
# Country
# Afghanistan                                               NaN            NaN
# Albania                                                   NaN            NaN
# Algeria                                                   NaN            NaN
# Angola                                                    NaN            NaN
# Argentina                                                 NaN            NaN
# Armenia                                                   NaN            NaN
# Australia                                                63.5            1.1
# Austria                                                  80.6            0.5
# Azerbaijan                                                NaN            NaN
# Bahrain                                                   NaN            NaN
# Bangladesh                                                NaN            NaN
# Belarus                                                   NaN            NaN
# Belgium                                                  70.1            1.0
# Belize                                                    NaN            NaN
# Benin                                                     NaN            NaN
# Bhutan                                                    NaN            NaN
# Bolivia                                                   NaN            NaN
# Bosnia and Herzegovina                                    NaN            NaN
# Botswana                                                  NaN            NaN
# Brazil                                                   35.6           26.7
# Bulgaria                                                  NaN            NaN
# Burkina Faso                                              NaN            NaN
# Burundi                                                   NaN            NaN
# Cambodia                                                  NaN            NaN
# Cameroon                                                  NaN            NaN
# Canada                                                   82.2            1.3
# Central African Republic                                  NaN            NaN
# Chad                                                      NaN            NaN
# Chile                                                    47.9            4.2
# China                                                     NaN            NaN
# ...                                                       ...            ...
# South Africa                                             36.1           13.7
# South Korea                                               NaN            NaN
# South Sudan                                               NaN            NaN
# Spain                                                    82.1            0.6
# Sri Lanka                                                 NaN            NaN
# Sudan                                                     NaN            NaN
# Sweden                                                   75.6            0.9
# Switzerland                                              85.3            0.6
# Syria                                                     NaN            NaN
# Taiwan                                                    NaN            NaN
# Tajikistan                                                NaN            NaN
# Tanzania                                                  NaN            NaN
# Thailand                                                  NaN            NaN
# Togo                                                      NaN            NaN
# Trinidad and Tobago                                       NaN            NaN
# Tunisia                                                   NaN            NaN
# Turkey                                                   59.8            1.4
# Turkmenistan                                              NaN            NaN
# Uganda                                                    NaN            NaN
# Ukraine                                                   NaN            NaN
# United Arab Emirates                                      NaN            NaN
# United Kingdom                                           77.7            0.2
# United States                                            73.9            5.5
# Uruguay                                                   NaN            NaN
# Uzbekistan                                                NaN            NaN
# Venezuela                                                 NaN            NaN
# Vietnam                                                   NaN            NaN
# Yemen                                                     NaN            NaN
# Zambia                                                    NaN            NaN
# Zimbabwe                                                  NaN            NaN
#
# Indicator                 Household net adjusted disposable income  \
# Country
# Afghanistan                                                    NaN
# Albania                                                        NaN
# Algeria                                                        NaN
# Angola                                                         NaN
# Argentina                                                      NaN
# Armenia                                                        NaN
# Australia                                                  32759.0
# Austria                                                    33541.0
# Azerbaijan                                                     NaN
# Bahrain                                                        NaN
# Bangladesh                                                     NaN
# Belarus                                                        NaN
# Belgium                                                    30364.0
# Belize                                                         NaN
# Benin                                                          NaN
# Bhutan                                                         NaN
# Bolivia                                                        NaN
# Bosnia and Herzegovina                                         NaN
# Botswana                                                       NaN
# Brazil                                                         NaN
# Bulgaria                                                       NaN
# Burkina Faso                                                   NaN
# Burundi                                                        NaN
# Cambodia                                                       NaN
# Cameroon                                                       NaN
# Canada                                                     30854.0
# Central African Republic                                       NaN
# Chad                                                           NaN
# Chile                                                          NaN
# China                                                          NaN
# ...                                                            ...
# South Africa                                                   NaN
# South Korea                                                    NaN
# South Sudan                                                    NaN
# Spain                                                      23999.0
# Sri Lanka                                                      NaN
# Sudan                                                          NaN
# Sweden                                                     31287.0
# Switzerland                                                37466.0
# Syria                                                          NaN
# Taiwan                                                         NaN
# Tajikistan                                                     NaN
# Tanzania                                                       NaN
# Thailand                                                       NaN
# Togo                                                           NaN
# Trinidad and Tobago                                            NaN
# Tunisia                                                        NaN
# Turkey                                                         NaN
# Turkmenistan                                                   NaN
# Uganda                                                         NaN
# Ukraine                                                        NaN
# United Arab Emirates                                           NaN
# United Kingdom                                             28715.0
# United States                                              45284.0
# Uruguay                                                        NaN
# Uzbekistan                                                     NaN
# Venezuela                                                      NaN
# Vietnam                                                        NaN
# Yemen                                                          NaN
# Zambia                                                         NaN
# Zimbabwe                                                       NaN
#
# Indicator                 Household net wealth  Housing expenditure  ...  \
# Country                                                              ...
# Afghanistan                                NaN                  NaN  ...
# Albania                                    NaN                  NaN  ...
# Algeria                                    NaN                  NaN  ...
# Angola                                     NaN                  NaN  ...
# Argentina                                  NaN                  NaN  ...
# Armenia                                    NaN                  NaN  ...
# Australia                             427064.0                 20.0  ...
# Austria                               308325.0                 21.0  ...
# Azerbaijan                                 NaN                  NaN  ...
# Bahrain                                    NaN                  NaN  ...
# Bangladesh                                 NaN                  NaN  ...
# Belarus                                    NaN                  NaN  ...
# Belgium                               386006.0                 21.0  ...
# Belize                                     NaN                  NaN  ...
# Benin                                      NaN                  NaN  ...
# Bhutan                                     NaN                  NaN  ...
# Bolivia                                    NaN                  NaN  ...
# Bosnia and Herzegovina                     NaN                  NaN  ...
# Botswana                                   NaN                  NaN  ...
# Brazil                                     NaN                  NaN  ...
# Bulgaria                                   NaN                  NaN  ...
# Burkina Faso                               NaN                  NaN  ...
# Burundi                                    NaN                  NaN  ...
# Cambodia                                   NaN                  NaN  ...
# Cameroon                                   NaN                  NaN  ...
# Canada                                423849.0                 22.0  ...
# Central African Republic                   NaN                  NaN  ...
# Chad                                       NaN                  NaN  ...
# Chile                                 100967.0                 18.0  ...
# China                                      NaN                  NaN  ...
# ...                                        ...                  ...  ...
# South Africa                               NaN                 18.0  ...
# South Korea                                NaN                  NaN  ...
# South Sudan                                NaN                  NaN  ...
# Spain                                 373548.0                 21.0  ...
# Sri Lanka                                  NaN                  NaN  ...
# Sudan                                      NaN                  NaN  ...
# Sweden                                     NaN                 19.0  ...
# Switzerland                                NaN                 22.0  ...
# Syria                                      NaN                  NaN  ...
# Taiwan                                     NaN                  NaN  ...
# Tajikistan                                 NaN                  NaN  ...
# Tanzania                                   NaN                  NaN  ...
# Thailand                                   NaN                  NaN  ...
# Togo                                       NaN                  NaN  ...
# Trinidad and Tobago                        NaN                  NaN  ...
# Tunisia                                    NaN                  NaN  ...
# Turkey                                     NaN                 20.0  ...
# Turkmenistan                               NaN                  NaN  ...
# Uganda                                     NaN                  NaN  ...
# Ukraine                                    NaN                  NaN  ...
# United Arab Emirates                       NaN                  NaN  ...
# United Kingdom                        548392.0                 26.0  ...
# United States                         632100.0                 19.0  ...
# Uruguay                                    NaN                  NaN  ...
# Uzbekistan                                 NaN                  NaN  ...
# Venezuela                                  NaN                  NaN  ...
# Vietnam                                    NaN                  NaN  ...
# Yemen                                      NaN                  NaN  ...
# Zambia                                     NaN                  NaN  ...
# Zimbabwe                                   NaN                  NaN  ...
#
# Indicator                 Quality of support network  Rooms per person  Score  \
# Country
# Afghanistan                                      NaN               NaN  3.632
# Albania                                          NaN               NaN  4.586
# Algeria                                          NaN               NaN  5.295
# Angola                                           NaN               NaN  3.795
# Argentina                                        NaN               NaN  6.388
# Armenia                                          NaN               NaN  4.321
# Australia                                       95.0               NaN  7.272
# Austria                                         92.0               1.6  7.139
# Azerbaijan                                       NaN               NaN  5.201
# Bahrain                                          NaN               NaN  6.105
# Bangladesh                                       NaN               NaN  4.500
# Belarus                                          NaN               NaN  5.483
# Belgium                                         91.0               2.2  6.927
# Belize                                           NaN               NaN  5.956
# Benin                                            NaN               NaN  4.141
# Bhutan                                           NaN               NaN  5.082
# Bolivia                                          NaN               NaN  5.752
# Bosnia and Herzegovina                           NaN               NaN  5.129
# Botswana                                         NaN               NaN  3.590
# Brazil                                          90.0               NaN  6.419
# Bulgaria                                         NaN               NaN  4.933
# Burkina Faso                                     NaN               NaN  4.424
# Burundi                                          NaN               NaN  2.905
# Cambodia                                         NaN               NaN  4.433
# Cameroon                                         NaN               NaN  4.975
# Canada                                          93.0               2.6  7.328
# Central African Republic                         NaN               NaN  3.083
# Chad                                             NaN               NaN  4.301
# Chile                                           85.0               1.2  6.476
# China                                            NaN               NaN  5.246
# ...                                              ...               ...    ...
# South Africa                                    88.0               NaN  4.724
# South Korea                                      NaN               NaN  5.875
# South Sudan                                      NaN               NaN  3.254
# Spain                                           93.0               1.9  6.310
# Sri Lanka                                        NaN               NaN  4.471
# Sudan                                            NaN               NaN  4.139
# Sweden                                          91.0               1.7  7.314
# Switzerland                                     93.0               1.9  7.487
# Syria                                            NaN               NaN  3.462
# Taiwan                                           NaN               NaN  6.441
# Tajikistan                                       NaN               NaN  5.358
# Tanzania                                         NaN               NaN  3.303
# Thailand                                         NaN               NaN  6.072
# Togo                                             NaN               NaN  3.999
# Trinidad and Tobago                              NaN               NaN  6.192
# Tunisia                                          NaN               NaN  4.592
# Turkey                                          86.0               1.0  5.483
# Turkmenistan                                     NaN               NaN  5.636
# Uganda                                           NaN               NaN  4.161
# Ukraine                                          NaN               NaN  4.103
# United Arab Emirates                             NaN               NaN  6.774
# United Kingdom                                  94.0               1.9  6.814
# United States                                   91.0               2.4  6.886
# Uruguay                                          NaN               NaN  6.379
# Uzbekistan                                       NaN               NaN  6.096
# Venezuela                                        NaN               NaN  4.806
# Vietnam                                          NaN               NaN  5.103
# Yemen                                            NaN               NaN  3.355
# Zambia                                           NaN               NaN  4.377
# Zimbabwe                                         NaN               NaN  3.692
#
# Indicator                 Self-reported health  \
# Country
# Afghanistan                                NaN
# Albania                                    NaN
# Algeria                                    NaN
# Angola                                     NaN
# Argentina                                  NaN
# Armenia                                    NaN
# Australia                                 85.0
# Austria                                   70.0
# Azerbaijan                                 NaN
# Bahrain                                    NaN
# Bangladesh                                 NaN
# Belarus                                    NaN
# Belgium                                   74.0
# Belize                                     NaN
# Benin                                      NaN
# Bhutan                                     NaN
# Bolivia                                    NaN
# Bosnia and Herzegovina                     NaN
# Botswana                                   NaN
# Brazil                                     NaN
# Bulgaria                                   NaN
# Burkina Faso                               NaN
# Burundi                                    NaN
# Cambodia                                   NaN
# Cameroon                                   NaN
# Canada                                    88.0
# Central African Republic                   NaN
# Chad                                       NaN
# Chile                                     57.0
# China                                      NaN
# ...                                        ...
# South Africa                               NaN
# South Korea                                NaN
# South Sudan                                NaN
# Spain                                     72.0
# Sri Lanka                                  NaN
# Sudan                                      NaN
# Sweden                                    75.0
# Switzerland                               78.0
# Syria                                      NaN
# Taiwan                                     NaN
# Tajikistan                                 NaN
# Tanzania                                   NaN
# Thailand                                   NaN
# Togo                                       NaN
# Trinidad and Tobago                        NaN
# Tunisia                                    NaN
# Turkey                                    69.0
# Turkmenistan                               NaN
# Uganda                                     NaN
# Ukraine                                    NaN
# United Arab Emirates                       NaN
# United Kingdom                            69.0
# United States                             88.0
# Uruguay                                    NaN
# Uzbekistan                                 NaN
# Venezuela                                  NaN
# Vietnam                                    NaN
# Yemen                                      NaN
# Zambia                                     NaN
# Zimbabwe                                   NaN
#
# Indicator                 Stakeholder engagement for developing regulations  \
# Country
# Afghanistan                                                             NaN
# Albania                                                                 NaN
# Algeria                                                                 NaN
# Angola                                                                  NaN
# Argentina                                                               NaN
# Armenia                                                                 NaN
# Australia                                                               2.7
# Austria                                                                 1.3
# Azerbaijan                                                              NaN
# Bahrain                                                                 NaN
# Bangladesh                                                              NaN
# Belarus                                                                 NaN
# Belgium                                                                 2.0
# Belize                                                                  NaN
# Benin                                                                   NaN
# Bhutan                                                                  NaN
# Bolivia                                                                 NaN
# Bosnia and Herzegovina                                                  NaN
# Botswana                                                                NaN
# Brazil                                                                  2.2
# Bulgaria                                                                NaN
# Burkina Faso                                                            NaN
# Burundi                                                                 NaN
# Cambodia                                                                NaN
# Cameroon                                                                NaN
# Canada                                                                  2.9
# Central African Republic                                                NaN
# Chad                                                                    NaN
# Chile                                                                   1.3
# China                                                                   NaN
# ...                                                                     ...
# South Africa                                                            NaN
# South Korea                                                             NaN
# South Sudan                                                             NaN
# Spain                                                                   1.8
# Sri Lanka                                                               NaN
# Sudan                                                                   NaN
# Sweden                                                                  2.0
# Switzerland                                                             2.3
# Syria                                                                   NaN
# Taiwan                                                                  NaN
# Tajikistan                                                              NaN
# Tanzania                                                                NaN
# Thailand                                                                NaN
# Togo                                                                    NaN
# Trinidad and Tobago                                                     NaN
# Tunisia                                                                 NaN
# Turkey                                                                  1.5
# Turkmenistan                                                            NaN
# Uganda                                                                  NaN
# Ukraine                                                                 NaN
# United Arab Emirates                                                    NaN
# United Kingdom                                                          3.1
# United States                                                           3.1
# Uruguay                                                                 NaN
# Uzbekistan                                                              NaN
# Venezuela                                                               NaN
# Vietnam                                                                 NaN
# Yemen                                                                   NaN
# Zambia                                                                  NaN
# Zimbabwe                                                                NaN
#
# Indicator                 Student skills  \
# Country
# Afghanistan                          NaN
# Albania                              NaN
# Algeria                              NaN
# Angola                               NaN
# Argentina                            NaN
# Armenia                              NaN
# Australia                          502.0
# Austria                            492.0
# Azerbaijan                           NaN
# Bahrain                              NaN
# Bangladesh                           NaN
# Belarus                              NaN
# Belgium                            503.0
# Belize                               NaN
# Benin                                NaN
# Bhutan                               NaN
# Bolivia                              NaN
# Bosnia and Herzegovina               NaN
# Botswana                             NaN
# Brazil                             395.0
# Bulgaria                             NaN
# Burkina Faso                         NaN
# Burundi                              NaN
# Cambodia                             NaN
# Cameroon                             NaN
# Canada                             523.0
# Central African Republic             NaN
# Chad                                 NaN
# Chile                              443.0
# China                                NaN
# ...                                  ...
# South Africa                         NaN
# South Korea                          NaN
# South Sudan                          NaN
# Spain                              491.0
# Sri Lanka                            NaN
# Sudan                                NaN
# Sweden                             496.0
# Switzerland                        506.0
# Syria                                NaN
# Taiwan                               NaN
# Tajikistan                           NaN
# Tanzania                             NaN
# Thailand                             NaN
# Togo                                 NaN
# Trinidad and Tobago                  NaN
# Tunisia                              NaN
# Turkey                             425.0
# Turkmenistan                         NaN
# Uganda                               NaN
# Ukraine                              NaN
# United Arab Emirates                 NaN
# United Kingdom                     500.0
# United States                      488.0
# Uruguay                              NaN
# Uzbekistan                           NaN
# Venezuela                            NaN
# Vietnam                              NaN
# Yemen                                NaN
# Zambia                               NaN
# Zimbabwe                             NaN
#
# Indicator                 Time devoted to leisure and personal care  \
# Country
# Afghanistan                                                     NaN
# Albania                                                         NaN
# Algeria                                                         NaN
# Angola                                                          NaN
# Argentina                                                       NaN
# Armenia                                                         NaN
# Australia                                                     14.35
# Austria                                                       14.55
# Azerbaijan                                                      NaN
# Bahrain                                                         NaN
# Bangladesh                                                      NaN
# Belarus                                                         NaN
# Belgium                                                       15.70
# Belize                                                          NaN
# Benin                                                           NaN
# Bhutan                                                          NaN
# Bolivia                                                         NaN
# Bosnia and Herzegovina                                          NaN
# Botswana                                                        NaN
# Brazil                                                          NaN
# Bulgaria                                                        NaN
# Burkina Faso                                                    NaN
# Burundi                                                         NaN
# Cambodia                                                        NaN
# Cameroon                                                        NaN
# Canada                                                        14.56
# Central African Republic                                        NaN
# Chad                                                            NaN
# Chile                                                           NaN
# China                                                           NaN
# ...                                                             ...
# South Africa                                                  14.92
# South Korea                                                     NaN
# South Sudan                                                     NaN
# Spain                                                         15.93
# Sri Lanka                                                       NaN
# Sudan                                                           NaN
# Sweden                                                        15.18
# Switzerland                                                     NaN
# Syria                                                           NaN
# Taiwan                                                          NaN
# Tajikistan                                                      NaN
# Tanzania                                                        NaN
# Thailand                                                        NaN
# Togo                                                            NaN
# Trinidad and Tobago                                             NaN
# Tunisia                                                         NaN
# Turkey                                                        14.79
# Turkmenistan                                                    NaN
# Uganda                                                          NaN
# Ukraine                                                         NaN
# United Arab Emirates                                            NaN
# United Kingdom                                                14.92
# United States                                                 14.44
# Uruguay                                                         NaN
# Uzbekistan                                                      NaN
# Venezuela                                                       NaN
# Vietnam                                                         NaN
# Yemen                                                           NaN
# Zambia                                                          NaN
# Zimbabwe                                                        NaN
#
# Indicator                 Voter turnout  Water quality  Years in education
# Country
# Afghanistan                         NaN            NaN                 NaN
# Albania                             NaN            NaN                 NaN
# Algeria                             NaN            NaN                 NaN
# Angola                              NaN            NaN                 NaN
# Argentina                           NaN            NaN                 NaN
# Armenia                             NaN            NaN                 NaN
# Australia                          91.0           93.0                21.0
# Austria                            80.0           92.0                17.0
# Azerbaijan                          NaN            NaN                 NaN
# Bahrain                             NaN            NaN                 NaN
# Bangladesh                          NaN            NaN                 NaN
# Belarus                             NaN            NaN                 NaN
# Belgium                            89.0           84.0                19.3
# Belize                              NaN            NaN                 NaN
# Benin                               NaN            NaN                 NaN
# Bhutan                              NaN            NaN                 NaN
# Bolivia                             NaN            NaN                 NaN
# Bosnia and Herzegovina              NaN            NaN                 NaN
# Botswana                            NaN            NaN                 NaN
# Brazil                             79.0           73.0                16.2
# Bulgaria                            NaN            NaN                 NaN
# Burkina Faso                        NaN            NaN                 NaN
# Burundi                             NaN            NaN                 NaN
# Cambodia                            NaN            NaN                 NaN
# Cameroon                            NaN            NaN                 NaN
# Canada                             68.0           91.0                17.3
# Central African Republic            NaN            NaN                 NaN
# Chad                                NaN            NaN                 NaN
# Chile                              47.0           71.0                17.5
# China                               NaN            NaN                 NaN
# ...                                 ...            ...                 ...
# South Africa                       73.0           67.0                 NaN
# South Korea                         NaN            NaN                 NaN
# South Sudan                         NaN            NaN                 NaN
# Spain                              70.0           72.0                17.9
# Sri Lanka                           NaN            NaN                 NaN
# Sudan                               NaN            NaN                 NaN
# Sweden                             86.0           96.0                19.3
# Switzerland                        49.0           95.0                17.5
# Syria                               NaN            NaN                 NaN
# Taiwan                              NaN            NaN                 NaN
# Tajikistan                          NaN            NaN                 NaN
# Tanzania                            NaN            NaN                 NaN
# Thailand                            NaN            NaN                 NaN
# Togo                                NaN            NaN                 NaN
# Trinidad and Tobago                 NaN            NaN                 NaN
# Tunisia                             NaN            NaN                 NaN
# Turkey                             86.0           65.0                18.3
# Turkmenistan                        NaN            NaN                 NaN
# Uganda                              NaN            NaN                 NaN
# Ukraine                             NaN            NaN                 NaN
# United Arab Emirates                NaN            NaN                 NaN
# United Kingdom                     69.0           84.0                17.5
# United States                      65.0           83.0                17.2
# Uruguay                             NaN            NaN                 NaN
# Uzbekistan                          NaN            NaN                 NaN
# Venezuela                           NaN            NaN                 NaN
# Vietnam                             NaN            NaN                 NaN
# Yemen                               NaN            NaN                 NaN
# Zambia                              NaN            NaN                 NaN
# Zimbabwe                            NaN            NaN                 NaN
#
# [159 rows x 25 columns]

# %%
shjoecddata0713.columns
# Out:
# Index(['Air pollution', 'Dwellings without basic facilities',
#        'Educational attainment', 'Employees working very long hours',
#        'Employment rate', 'Feeling safe walking alone at night',
#        'Homicide rate', 'Household net adjusted disposable income',
#        'Household net wealth', 'Housing expenditure',
#        'Labour market insecurity', 'Life expectancy', 'Life satisfaction',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Rooms per person', 'Score',
#        'Self-reported health',
#        'Stakeholder engagement for developing regulations', 'Student skills',
#        'Time devoted to leisure and personal care', 'Voter turnout',
#        'Water quality', 'Years in education'],
#       dtype='object', name='Indicator')

# %%
shjoecddata0713_drop = shjoecddata0713.dropna(how="any")
shjoecddata0713_drop
# Out:
# Indicator       Air pollution  Dwellings without basic facilities  \
# Country
# Austria                  16.0                                 0.9
# Belgium                  15.0                                 1.9
# Canada                    7.0                                 0.2
# Denmark                   9.0                                 0.5
# Estonia                   8.0                                 7.0
# Finland                   6.0                                 0.5
# France                   13.0                                 0.5
# Germany                  14.0                                 0.2
# Italy                    18.0                                 0.7
# Latvia                   11.0                                13.9
# Poland                   22.0                                 3.0
# Slovenia                 16.0                                 0.4
# Spain                    11.0                                 0.1
# United Kingdom           11.0                                 0.3
# United States            10.0                                 0.1
#
# Indicator       Educational attainment  Employees working very long hours  \
# Country
# Austria                           85.0                               6.66
# Belgium                           77.0                               4.75
# Canada                            91.0                               3.69
# Denmark                           81.0                               2.34
# Estonia                           89.0                               2.42
# Finland                           88.0                               3.81
# France                            78.0                               7.67
# Germany                           87.0                               4.26
# Italy                             61.0                               4.11
# Latvia                            88.0                               1.27
# Poland                            92.0                               5.95
# Slovenia                          88.0                               4.39
# Spain                             59.0                               4.01
# United Kingdom                    81.0                              12.15
# United States                     91.0                              11.09
#
# Indicator       Employment rate  Feeling safe walking alone at night  \
# Country
# Austria                    72.0                                 80.6
# Belgium                    63.0                                 70.1
# Canada                     73.0                                 82.2
# Denmark                    74.0                                 83.5
# Estonia                    74.0                                 69.0
# Finland                    70.0                                 85.1
# France                     65.0                                 70.5
# Germany                    75.0                                 72.5
# Italy                      58.0                                 58.4
# Latvia                     70.0                                 62.4
# Poland                     66.0                                 67.3
# Slovenia                   69.0                                 86.1
# Spain                      62.0                                 82.1
# United Kingdom             75.0                                 77.7
# United States              70.0                                 73.9
#
# Indicator       Homicide rate  Household net adjusted disposable income  \
# Country
# Austria                   0.5                                   33541.0
# Belgium                   1.0                                   30364.0
# Canada                    1.3                                   30854.0
# Denmark                   0.6                                   29606.0
# Estonia                   3.1                                   19697.0
# Finland                   1.3                                   29943.0
# France                    0.5                                   31304.0
# Germany                   0.5                                   34294.0
# Italy                     0.6                                   26588.0
# Latvia                    4.8                                   16275.0
# Poland                    0.7                                   19814.0
# Slovenia                  0.6                                   20820.0
# Spain                     0.6                                   23999.0
# United Kingdom            0.2                                   28715.0
# United States             5.5                                   45284.0
#
# Indicator       Household net wealth  Housing expenditure  ...  \
# Country                                                    ...
# Austria                     308325.0                 21.0  ...
# Belgium                     386006.0                 21.0  ...
# Canada                      423849.0                 22.0  ...
# Denmark                     118637.0                 23.0  ...
# Estonia                     159373.0                 17.0  ...
# Finland                     200827.0                 23.0  ...
# France                      280653.0                 21.0  ...
# Germany                     259667.0                 20.0  ...
# Italy                       279889.0                 23.0  ...
# Latvia                       70160.0                 23.0  ...
# Poland                      210991.0                 22.0  ...
# Slovenia                    203044.0                 18.0  ...
# Spain                       373548.0                 21.0  ...
# United Kingdom              548392.0                 26.0  ...
# United States               632100.0                 19.0  ...
#
# Indicator       Quality of support network  Rooms per person  Score  \
# Country
# Austria                               92.0               1.6  7.139
# Belgium                               91.0               2.2  6.927
# Canada                                93.0               2.6  7.328
# Denmark                               95.0               1.9  7.555
# Estonia                               92.0               1.6  5.739
# Finland                               95.0               1.9  7.632
# France                                90.0               1.8  6.489
# Germany                               90.0               1.8  6.965
# Italy                                 92.0               1.4  6.000
# Latvia                                86.0               1.2  5.933
# Poland                                86.0               1.1  6.123
# Slovenia                              92.0               1.5  5.948
# Spain                                 93.0               1.9  6.310
# United Kingdom                        94.0               1.9  6.814
# United States                         91.0               2.4  6.886
#
# Indicator       Self-reported health  \
# Country
# Austria                         70.0
# Belgium                         74.0
# Canada                          88.0
# Denmark                         71.0
# Estonia                         53.0
# Finland                         70.0
# France                          66.0
# Germany                         65.0
# Italy                           71.0
# Latvia                          47.0
# Poland                          58.0
# Slovenia                        64.0
# Spain                           72.0
# United Kingdom                  69.0
# United States                   88.0
#
# Indicator       Stakeholder engagement for developing regulations  \
# Country
# Austria                                                       1.3
# Belgium                                                       2.0
# Canada                                                        2.9
# Denmark                                                       2.0
# Estonia                                                       2.7
# Finland                                                       2.2
# France                                                        2.1
# Germany                                                       1.8
# Italy                                                         2.5
# Latvia                                                        2.2
# Poland                                                        2.6
# Slovenia                                                      2.5
# Spain                                                         1.8
# United Kingdom                                                3.1
# United States                                                 3.1
#
# Indicator       Student skills  Time devoted to leisure and personal care  \
# Country
# Austria                  492.0                                      14.55
# Belgium                  503.0                                      15.70
# Canada                   523.0                                      14.56
# Denmark                  504.0                                      15.87
# Estonia                  524.0                                      14.90
# Finland                  523.0                                      15.17
# France                   496.0                                      16.36
# Germany                  508.0                                      15.62
# Italy                    485.0                                      16.47
# Latvia                   487.0                                      13.83
# Poland                   504.0                                      14.42
# Slovenia                 509.0                                      14.75
# Spain                    491.0                                      15.93
# United Kingdom           500.0                                      14.92
# United States            488.0                                      14.44
#
# Indicator       Voter turnout  Water quality  Years in education
# Country
# Austria                  80.0           92.0                17.0
# Belgium                  89.0           84.0                19.3
# Canada                   68.0           91.0                17.3
# Denmark                  86.0           95.0                19.5
# Estonia                  64.0           84.0                17.7
# Finland                  67.0           95.0                19.8
# France                   75.0           81.0                16.5
# Germany                  76.0           91.0                18.1
# Italy                    73.0           71.0                16.6
# Latvia                   59.0           79.0                18.0
# Poland                   55.0           82.0                17.6
# Slovenia                 53.0           90.0                18.3
# Spain                    70.0           72.0                17.9
# United Kingdom           69.0           84.0                17.5
# United States            65.0           83.0                17.2
#
# [15 rows x 25 columns]

# %%
outputfile = oecddata2.to_csv("oecddatareduced0713.csv", encoding="utf-8", index=False)

# %%
shjoecddata0713_drop.columns
# Out:
# Index(['Air pollution', 'Dwellings without basic facilities',
#        'Educational attainment', 'Employees working very long hours',
#        'Employment rate', 'Feeling safe walking alone at night',
#        'Homicide rate', 'Household net adjusted disposable income',
#        'Household net wealth', 'Housing expenditure',
#        'Labour market insecurity', 'Life expectancy', 'Life satisfaction',
#        'Long-term unemployment rate', 'Personal earnings',
#        'Quality of support network', 'Rooms per person', 'Score',
#        'Self-reported health',
#        'Stakeholder engagement for developing regulations', 'Student skills',
#        'Time devoted to leisure and personal care', 'Voter turnout',
#        'Water quality', 'Years in education'],
#       dtype='object', name='Indicator')

# %%
columns = list(shjoecddata0713_drop.columns)

# %%
for indicator in columns:
    plt.scatter(shjoecddata0713_drop["Score"], shjoecddata0713_drop[indicator], edgecolor="black", alpha=0.7)
    plt.xlim(len(shjoecddata0713_drop))
    plt.ylim(min(shjoecddata0713_drop[indicator])-1, max(shjoecddata0713_drop[indicator])+1)
    plt.grid()

    plt.title(f"Happiness Rank vs. {indicator}")
    plt.xlabel("Happiness Rank")
    plt.ylabel(indicator)
    plt.show()

# %%
coefficient_list = []

for indicator in columns:
   coefficient = np.corrcoef(shjoecddata0713_drop["Score"], shjoecddata0713_drop[indicator])
   coefficient_list.append(coefficient[0][1])

# %%
coefficient_list
# Out:
# [-0.4344531998122721,
#  -0.5109452440139673,
#  0.18688523514526714,
#  0.15287281033151542,
#  0.3876847455098301,
#  0.580641684080035,
#  -0.21337453083033647,
#  0.6602419781733799,
#  0.26410730587608133,
#  0.354062452909868,
#  -0.37546628590166437,
#  0.3547892571554826,
#  0.9988602883082817,
#  -0.4626429435680053,
#  0.7799564363731031,
#  0.5532483564631075,
#  0.6465043983356191,
#  1.0,
#  0.6158498067876964,
#  -0.19915427727938118,
#  0.2685093959777692,
#  0.08693193675836981,
#  0.5697571497739644,
#  0.6893668568663033,
#  0.43098884437038026]

# %%
#creating a table of coefficients to show which are most correlated
coeff_pd = pd.DataFrame({"Factor":columns,"Coefficient":coefficient_list})
coeff_pd = coeff_pd.sort_values("Coefficient", axis = 0, ascending = False)
coeff_pd["Coefficient"] = round(coeff_pd["Coefficient"],2)
coeff_pd
# Out:
#                                                Factor  Coefficient
# 17                                              Score         1.00
# 12                                  Life satisfaction         1.00
# 14                                  Personal earnings         0.78
# 23                                      Water quality         0.69
# 7            Household net adjusted disposable income         0.66
# 16                                   Rooms per person         0.65
# 18                               Self-reported health         0.62
# 5                 Feeling safe walking alone at night         0.58
# 22                                      Voter turnout         0.57
# 15                         Quality of support network         0.55
# 24                                 Years in education         0.43
# 4                                     Employment rate         0.39
# 11                                    Life expectancy         0.35
# 9                                 Housing expenditure         0.35
# 20                                     Student skills         0.27
# 8                                Household net wealth         0.26
# 2                              Educational attainment         0.19
# 3                   Employees working very long hours         0.15
# 21          Time devoted to leisure and personal care         0.09
# 19  Stakeholder engagement for developing regulations        -0.20
# 6                                       Homicide rate        -0.21
# 10                           Labour market insecurity        -0.38
# 0                                       Air pollution        -0.43
# 13                        Long-term unemployment rate        -0.46
# 1                  Dwellings without basic facilities        -0.51

# %%
fig, ax = plt.subplots(figsize=(10, 6)) # set size frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis
ax.set_frame_on(False)  # no visible frame, uncomment if size is ok
tabla = table(ax, coeff_pd, loc='upper right', colWidths=[0.17]*len(coeff_pd.columns))  # where df is your data frame
tabla.auto_set_font_size(False) # Activate set fontsize manually
tabla.set_fontsize(15) # if ++fontsize is necessary ++colWidths
tabla.scale(5, 4) # change size table
plt.savefig('table.png', transparent=True)

# %%
#Create bar graph of coefficients
summarybar = plt.bar(coeff_pd["Factor"],coeff_pd["Coefficient"])
plt.xlabel("Factors")
plt.ylabel("Correlation Coefficient")
plt.title("OECD Countries - Factors Related to Happiness")
plt.ylim(-1,1)
plt.xticks(coeff_pd["Factor"],rotation=65)

plt.plot(figsize = (10,10))


for bar in summarybar:
    height = bar.get_height()
    if height > 0:
        label_position=-0.25
    else:
        label_position = 0.01
    plt.text(bar.get_x()+bar.get_width()/2.,label_position,
            round(height*100,0),color='black',
            ha='center',va='bottom')

plt.tight_layout()
plt.savefig("OECD_countries_factors")
